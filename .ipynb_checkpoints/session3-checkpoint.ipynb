# %%
import pandas as pd
import pickle
import requests as rq
import json
import math

# %%
df = pd.read_pickle("objects_saved/data.pkl")

# %%
with open('objects_saved/isocodes.pkl', 'rb') as handle:
  isocodes = pickle.load(handle)
isocodes

# %%
with open('data_files/yidaiyilu_api_data.json', 'r') as handle:
  data = json.load(handle)

# %%
yidaiyilu_data = {}

# %%
# 2015 year
year = "65d2ea03425887a717c435081cfc5dbb" 

# useful indicators for scrapping
indicators = {
    "9b688b5fbb441714ba73f4379e7b135d": "BRI GDP",
    "5c4591fe4746333f6e7b66b13ad980a2": "BRI GDP growth rate",
    "6d602224213550f3ee07477f1654f326": "BRI GDP p.c.",
    "07f451a8c9b2006fb937d1eb268ac60b": "BRI Y.o.Y. GDP growth rate p.c.",
    "c1329b4c01d4c08a68b8a280fb5a90ec": "BRI Agriculture value added per sector ",
    "f00273fa66d45147b2dd4dadd6275d32": "BRI Industry value added per sector ",
    "41fedd97a26d4782e531b5b4c67622b7": "BRI Services value added per sector ",
    "7b8d0a597b57bab793f428193eb899fe": "BRI Internet penetration rate (%)",
    "2a048dbe6ff2ee51d07a6314752c87d7": "BRI Population density (/km2)",
    "85bf6dab128029be54a3b1e643f0aa71": "BRI Percentage of Urban Population in Total Population"
}

# %%
# Get all countries available
for key_country in data['country_macro']['term']['area']:
    full_country_name = data['country_macro']['term']['area'][key_country]['full']
    
    for country in isocodes:
        if full_country_name in isocodes or full_country_name == isocodes[country]['other']:
            yidaiyilu_data[full_country_name] = {}

# %%
for key_country in data['country_macro']['term']['area']:
    full_country_name = data['country_macro']['term']['area'][key_country]['full']
    
    for key_indic in data['country_macro']['data'][year][key_country]:
        # Check if we care about this indicator
        if key_indic not in indicators:
            continue
        value = data['country_macro']['data'][year][key_country][key_indic]
        if value == '':
            continue
        yidaiyilu_data[full_country_name].update({indicators[key_indic] : value})

# %%
# We check how many countries data we have
len(yidaiyilu_data)
# Out:
# 63

# %%
yidaiyilu_data
# Out:
# {'Albania': {'BRI GDP': '11455595709.1413',
#   'BRI GDP growth rate': '2.55999999999999',
#   'BRI GDP p.c.': '3965.01680558488',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.71928006930717',
#   'BRI Agriculture value added per sector ': '22.0492060503358',
#   'BRI Industry value added per sector ': '26.1513054666415',
#   'BRI Services value added per sector ': '51.7994884830226',
#   'BRI Population density (/km2)': '105.444051094891',
#   'BRI Percentage of Urban Population in Total Population': '57.407'},
#  'Afghanistan': {'BRI GDP': '19199437988.8023',
#   'BRI GDP growth rate': '1.51991126448578',
#   'BRI GDP p.c.': '590.269515382605',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-1.28616720583651',
#   'BRI Agriculture value added per sector ': '22.6039268726035',
#   'BRI Industry value added per sector ': '22.4166817955447',
#   'BRI Services value added per sector ': '54.9793913318518',
#   'BRI Population density (/km2)': '49.8216493582085',
#   'BRI Percentage of Urban Population in Total Population': '26.703'},
#  'The United Arab Emirates': {'BRI GDP': '370292716133.424',
#   'BRI GDP growth rate': '3.18267819490927',
#   'BRI GDP p.c.': '40438.3763627115',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.38461774621288',
#   'BRI Population density (/km2)': '109.533050239234',
#   'BRI Percentage of Urban Population in Total Population': '85.541'},
#  'Oman': {'BRI GDP': '70254876462.9389',
#   'BRI GDP growth rate': '3.49999999999999',
#   'BRI GDP p.c.': '15645.0807292348',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-2.36546119944124',
#   'BRI Population density (/km2)': '14.5090177705977',
#   'BRI Percentage of Urban Population in Total Population': '77.641'},
#  'Azerbaijan': {'BRI GDP': '53047140347.4527',
#   'BRI GDP growth rate': '1.09999999999999',
#   'BRI GDP p.c.': '5496.34464026248',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-0.117953780347179',
#   'BRI Agriculture value added per sector ': '6.79136800335426',
#   'BRI Industry value added per sector ': '36.9931249761771',
#   'BRI Services value added per sector ': '56.2155070204686',
#   'BRI Population density (/km2)': '116.761018158942',
#   'BRI Percentage of Urban Population in Total Population': '54.62'},
#  'Egypt': {'BRI GDP': '330778550716.746',
#   'BRI GDP growth rate': '4.2',
#   'BRI GDP p.c.': '3614.74676616271',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.00412035727904',
#   'BRI Agriculture value added per sector ': '11.1816471975681',
#   'BRI Industry value added per sector ': '36.3195006150812',
#   'BRI Services value added per sector ': '52.498864387308',
#   'BRI Population density (/km2)': '91.9263488874378',
#   'BRI Percentage of Urban Population in Total Population': '43.135'},
#  'Estonia': {'BRI GDP': '22691482754.7965',
#   'BRI GDP growth rate': '1.06784053106526',
#   'BRI GDP p.c.': '17295.36383043',
#   'BRI Y.o.Y. GDP growth rate p.c.': '1.26404493826149',
#   'BRI Industry value added per sector ': '26.7491961759834',
#   'BRI Services value added per sector ': '69.7459447339573',
#   'BRI Population density (/km2)': '30.9506487379099',
#   'BRI Percentage of Urban Population in Total Population': '67.538'},
#  'Pakistan': {'BRI GDP': '269971498118.442',
#   'BRI GDP growth rate': '5.53810056237647',
#   'BRI GDP p.c.': '1428.98863660717',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.37030826529043',
#   'BRI Agriculture value added per sector ': '3.50485909005935',
#   'BRI Industry value added per sector ': '18.9918473602083',
#   'BRI Services value added per sector ': '55.5440889943875',
#   'BRI Population density (/km2)': '245.076891344956',
#   'BRI Percentage of Urban Population in Total Population': '38.758'},
#  'Bahrain': {'BRI GDP': '32221489361.7021',
#   'BRI GDP growth rate': '2.92656721719055',
#   'BRI GDP p.c.': '23395.7476902684',
#   'BRI Y.o.Y. GDP growth rate p.c.': '1.78261235365325',
#   'BRI Agriculture value added per sector ': '25.4640636454042',
#   'BRI Industry value added per sector ': '41.3708969169512',
#   'BRI Services value added per sector ': '58.3286560442681',
#   'BRI Population density (/km2)': '1788.61948051948',
#   'BRI Percentage of Urban Population in Total Population': '88.775'},
#  'Belarus': {'BRI GDP': '54608962634.9908',
#   'BRI GDP growth rate': '-3.88769850231654',
#   'BRI GDP p.c.': '5740.45649479562',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-4.19079626799829',
#   'BRI Agriculture value added per sector ': '0.300447038780779',
#   'BRI Industry value added per sector ': '40.1472592179596',
#   'BRI Services value added per sector ': '52.0569624048448',
#   'BRI Population density (/km2)': '46.8828544674979',
#   'BRI Percentage of Urban Population in Total Population': '76.667'},
#  'Bulgaria': {'BRI GDP': '48952959079.5738',
#   'BRI GDP growth rate': '2.96713547854921',
#   'BRI GDP p.c.': '6819.86910816324',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.62623786163006',
#   'BRI Agriculture value added per sector ': '7.79577837719564',
#   'BRI Industry value added per sector ': '27.6133062083995',
#   'BRI Services value added per sector ': '67.2484864438402',
#   'BRI Population density (/km2)': '66.1200350036846',
#   'BRI Percentage of Urban Population in Total Population': '73.948'},
#  'Bosnia and Herzegovina': {'BRI GDP': '15995392117.9473',
#   'BRI GDP growth rate': '3.15757629916973',
#   'BRI GDP p.c.': '4197.80730449044',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.35081997115292',
#   'BRI Agriculture value added per sector ': '5.13820734776027',
#   'BRI Industry value added per sector ': '27.13001108395',
#   'BRI Services value added per sector ': '65.7655687803434',
#   'BRI Population density (/km2)': '74.4221875',
#   'BRI Percentage of Urban Population in Total Population': '39.767'},
#  'Poland': {'BRI GDP': '474783393022.947',
#   'BRI GDP growth rate': '3.64971913068008',
#   'BRI GDP p.c.': '12494.4661900747',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.68310842296589',
#   'BRI Agriculture value added per sector ': '7.10442013570666',
#   'BRI Industry value added per sector ': '33.541179641684',
#   'BRI Services value added per sector ': '63.6822741379658',
#   'BRI Population density (/km2)': '124.096188889977',
#   'BRI Percentage of Urban Population in Total Population': '60.539'},
#  'Bhutan': {'BRI GDP': '1962221695.69413',
#   'BRI GDP growth rate': '3.25425473889356',
#   'BRI GDP p.c.': '2532.45446832741',
#   'BRI Y.o.Y. GDP growth rate p.c.': '1.9453698350496',
#   'BRI Agriculture value added per sector ': '2.77654622035025',
#   'BRI Industry value added per sector ': '42.0790242339736',
#   'BRI Services value added per sector ': '40.8652126344372',
#   'BRI Population density (/km2)': '20.327675315476',
#   'BRI Percentage of Urban Population in Total Population': '38.644'},
#  'East Timor': {'BRI GDP': '1412377919.12175',
#   'BRI GDP growth rate': '4.251',
#   'BRI GDP p.c.': '1134.42642789183',
#   'BRI Y.o.Y. GDP growth rate p.c.': '1.49545736958994',
#   'BRI Agriculture value added per sector ': '17.0557631315892',
#   'BRI Population density (/km2)': '83.726630800269',
#   'BRI Percentage of Urban Population in Total Population': '32.77'},
#  'Russia': {'BRI GDP': '1326015096948.19',
#   'BRI GDP growth rate': '-3.72667344001421',
#   'BRI GDP p.c.': '9057.11306037766',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-3.9340216039501',
#   'BRI Industry value added per sector ': '32.6045564415853',
#   'BRI Services value added per sector ': '62.7653649153076',
#   'BRI Population density (/km2)': '8.7988005033929',
#   'BRI Percentage of Urban Population in Total Population': '74.008'},
#  'Philippines': {'BRI GDP': '291965336390.95',
#   'BRI GDP growth rate': '5.80572866285858',
#   'BRI GDP p.c.': '2899.37527818265',
#   'BRI Y.o.Y. GDP growth rate p.c.': '4.16588236832258',
#   'BRI Agriculture value added per sector ': '4.63007864310703',
#   'BRI Industry value added per sector ': '30.8898334926965',
#   'BRI Services value added per sector ': '58.843620179926',
#   'BRI Population density (/km2)': '337.724771103733',
#   'BRI Percentage of Urban Population in Total Population': '44.373'},
#  'Georgia': {'BRI GDP': '13965385801.7891',
#   'BRI GDP growth rate': '2.77492809454047',
#   'BRI GDP p.c.': '3795.97330845042',
#   'BRI Y.o.Y. GDP growth rate p.c.': '4.11583501178372',
#   'BRI Agriculture value added per sector ': '10.2665463273775',
#   'BRI Industry value added per sector ': '24.5206288020114',
#   'BRI Services value added per sector ': '66.2902111459188',
#   'BRI Population density (/km2)': '64.3654431575632',
#   'BRI Percentage of Urban Population in Total Population': '53.641'},
#  'Kazakhstan': {'BRI GDP': '184360630555.504',
#   'BRI GDP growth rate': '1.20000000000036',
#   'BRI GDP p.c.': '10508.3964031895',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-0.270354373879556',
#   'BRI Agriculture value added per sector ': '9.18916005206981',
#   'BRI Industry value added per sector ': '33.2279211309936',
#   'BRI Services value added per sector ': '61.7647613416438',
#   'BRI Population density (/km2)': '6.49854650516724',
#   'BRI Percentage of Urban Population in Total Population': '53.247'},
#  'Montenegro': {'BRI GDP': '3992640233.17019',
#   'BRI GDP growth rate': '3.37469381321137',
#   'BRI GDP p.c.': '6415.03408351413',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.27869168427566',
#   'BRI Agriculture value added per sector ': '5.00731752736254',
#   'BRI Industry value added per sector ': '20.3',
#   'BRI Services value added per sector ': '69.5',
#   'BRI Population density (/km2)': '46.2742007434944',
#   'BRI Percentage of Urban Population in Total Population': '64.026'},
#  'Kyrgyzstan': {'BRI GDP': '6571853849.00585',
#   'BRI GDP growth rate': '3.46928079781574',
#   'BRI GDP p.c.': '1103.2153515202',
#   'BRI Y.o.Y. GDP growth rate p.c.': '1.35890349096086',
#   'BRI Agriculture value added per sector ': '10.2',
#   'BRI Industry value added per sector ': '26.9157155736444',
#   'BRI Services value added per sector ': '57.1425849099294',
#   'BRI Population density (/km2)': '31.0583941605839',
#   'BRI Percentage of Urban Population in Total Population': '35.707'},
#  'Cambodia': {'BRI GDP': '18049954289.4301',
#   'BRI GDP growth rate': '7.03608717936477',
#   'BRI GDP p.c.': '1158.68990352486',
#   'BRI Y.o.Y. GDP growth rate p.c.': '5.3199601045789',
#   'BRI Agriculture value added per sector ': '15.9416995164261',
#   'BRI Industry value added per sector ': '29.4173723333596',
#   'BRI Services value added per sector ': '42.3334790133704',
#   'BRI Population density (/km2)': '88.250050985724',
#   'BRI Percentage of Urban Population in Total Population': '20.723'},
#  'Czech Republic': {'BRI GDP': '181811026983.078',
#   'BRI GDP growth rate': '4.19804965676525',
#   'BRI GDP p.c.': '17231.2817109642',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.94255198007787',
#   'BRI Agriculture value added per sector ': '28.2491486532701',
#   'BRI Industry value added per sector ': '38.091385170647',
#   'BRI Services value added per sector ': '59.5250579376435',
#   'BRI Population density (/km2)': '136.620730286158',
#   'BRI Percentage of Urban Population in Total Population': '72.992'},
#  'Qatar': {'BRI GDP': '166907692307.692',
#   'BRI GDP growth rate': '3.58277342974473',
#   'BRI GDP p.c.': '74667.1970705737',
#   'BRI Y.o.Y. GDP growth rate p.c.': '0.6500161136278',
#   'BRI Agriculture value added per sector ': '2.38355689170941',
#   'BRI Industry value added per sector ': '55.7613934134812',
#   'BRI Services value added per sector ': '44.1023201611735',
#   'BRI Population density (/km2)': '192.537037037037',
#   'BRI Percentage of Urban Population in Total Population': '99.244'},
#  'Kuwait': {'BRI GDP': '112811565304.088',
#   'BRI GDP growth rate': '-0.40000000000002',
#   'BRI GDP p.c.': '28984.6433890283',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-3.95688421333904',
#   'BRI Agriculture value added per sector ': '0.136286425345325',
#   'BRI Population density (/km2)': '218.412738496072',
#   'BRI Percentage of Urban Population in Total Population': '98.342'},
#  'Croatia': {'BRI GDP': '48732003674.38',
#   'BRI GDP growth rate': '1.64461325883687',
#   'BRI GDP p.c.': '11535.8293558997',
#   'BRI Y.o.Y. GDP growth rate p.c.': '1.98111041119844',
#   'BRI Industry value added per sector ': '26.2052927095021',
#   'BRI Services value added per sector ': '69.5038660647239',
#   'BRI Population density (/km2)': '75.4897069335239',
#   'BRI Percentage of Urban Population in Total Population': '58.964'},
#  'Latvia': {'BRI GDP': '27035266718.4208',
#   'BRI GDP growth rate': '1.88691229576618',
#   'BRI GDP p.c.': '13664.9414278021',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.67700398843398',
#   'BRI Agriculture value added per sector ': '4.29084122577397',
#   'BRI Population density (/km2)': '31.812831644959',
#   'BRI Percentage of Urban Population in Total Population': '67.382'},
#  'Laos': {'BRI GDP': '12327488340.7341',
#   'BRI GDP growth rate': '6.99522551975515',
#   'BRI GDP p.c.': '1812.32676524824',
#   'BRI Y.o.Y. GDP growth rate p.c.': '5.22210261113469',
#   'BRI Industry value added per sector ': '30.8744568625836',
#   'BRI Services value added per sector ': '41.8820332815012',
#   'BRI Population density (/km2)': '29.4715034662045',
#   'BRI Percentage of Urban Population in Total Population': '38.614'},
#  'Lebanon': {'BRI GDP': '47102873631.8408',
#   'BRI GDP growth rate': '1.50856704175307',
#   'BRI GDP p.c.': '8050.75075624426',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-2.63188400844915',
#   'BRI Agriculture value added per sector ': '27.2435098559153',
#   'BRI Industry value added per sector ': '20.6709620663426',
#   'BRI Services value added per sector ': '73.764035595287',
#   'BRI Population density (/km2)': '571.920136852395',
#   'BRI Percentage of Urban Population in Total Population': '87.792'},
#  'Lithuania': {'BRI GDP': '41243983586.5587',
#   'BRI GDP growth rate': '1.59377460567481',
#   'BRI GDP p.c.': '14172.2210702975',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.36764979271824',
#   'BRI Agriculture value added per sector ': '5.56500233837039',
#   'BRI Population density (/km2)': '46.4331711208616',
#   'BRI Percentage of Urban Population in Total Population': '66.508'},
#  'Romania': {'BRI GDP': '177954489851.961',
#   'BRI GDP growth rate': '3.73668357850366',
#   'BRI GDP p.c.': '8972.92251840971',
#   'BRI Y.o.Y. GDP growth rate p.c.': '4.13730059924066',
#   'BRI Industry value added per sector ': '26.4496323093554',
#   'BRI Services value added per sector ': '68.7912879062644',
#   'BRI Population density (/km2)': '86.2165326261792',
#   'BRI Percentage of Urban Population in Total Population': '54.564'},
#  'Maldives': {'BRI GDP': '3142812004.19099',
#   'BRI GDP growth rate': '1.51388419597605',
#   'BRI GDP p.c.': '7681.07576733719',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-0.511366955012065',
#   'BRI Agriculture value added per sector ': '4.75907978438019',
#   'BRI Population density (/km2)': '1363.87666666667',
#   'BRI Percentage of Urban Population in Total Population': '45.536'},
#  'Malaysia': {'BRI GDP': '296217641787.223',
#   'BRI GDP growth rate': '4.95237060557724',
#   'BRI GDP p.c.': '9766.16575200497',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.46789577381521',
#   'BRI Industry value added per sector ': '39.123658674467',
#   'BRI Services value added per sector ': '44.3003497343713',
#   'BRI Population density (/km2)': '92.3177811596408',
#   'BRI Percentage of Urban Population in Total Population': '74.705'},
#  'Macedonia': {'BRI GDP': '10086021260.9944',
#   'BRI GDP growth rate': '3.66528037380903',
#   'BRI GDP p.c.': '4852.65784744443',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.5242305579618',
#   'BRI Agriculture value added per sector ': '8.43079391258197',
#   'BRI Industry value added per sector ': '26.1379004321792',
#   'BRI Services value added per sector ': '62.7006451456147',
#   'BRI Population density (/km2)': '82.4128865979381',
#   'BRI Percentage of Urban Population in Total Population': '57.104'},
#  'Mongolia': {'BRI GDP': '11757940908.6277',
#   'BRI GDP growth rate': '2.29544361018836',
#   'BRI GDP p.c.': '3973.43983362286',
#   'BRI Y.o.Y. GDP growth rate p.c.': '0.592451978660804',
#   'BRI Agriculture value added per sector ': '11.1614544222061',
#   'BRI Industry value added per sector ': '34.0705088562784',
#   'BRI Services value added per sector ': '51.0797619902436',
#   'BRI Population density (/km2)': '1.90474394294395',
#   'BRI Percentage of Urban Population in Total Population': '72.04'},
#  'Bangladesh': {'BRI GDP': '195078665827.565',
#   'BRI GDP growth rate': '6.55263331602802',
#   'BRI GDP p.c.': '1211.70153057661',
#   'BRI Y.o.Y. GDP growth rate p.c.': '5.2831474252867',
#   'BRI Agriculture value added per sector ': '14.8497291534782',
#   'BRI Industry value added per sector ': '28.1463235005595',
#   'BRI Services value added per sector ': '56.3462045652581',
#   'BRI Population density (/km2)': '1236.81064761466',
#   'BRI Percentage of Urban Population in Total Population': '34.277'},
#  'Myanmar': {'BRI GDP': '64865515159.2277',
#   'BRI GDP growth rate': '6.99127097835952',
#   'BRI GDP p.c.': '1203.50538655951',
#   'BRI Y.o.Y. GDP growth rate p.c.': '6.07813464292907',
#   'BRI Agriculture value added per sector ': '15.5074719341824',
#   'BRI Population density (/km2)': '82.5276443927237',
#   'BRI Percentage of Urban Population in Total Population': '34.098'},
#  'Moldova': {'BRI GDP': '6551161404.09357',
#   'BRI GDP growth rate': '-0.5',
#   'BRI GDP p.c.': '1843.24280182141',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-0.437094241942518',
#   'BRI Industry value added per sector ': '17.9488668324983',
#   'BRI Services value added per sector ': '68.2206608845625',
#   'BRI Population density (/km2)': '123.764669011387',
#   'BRI Percentage of Urban Population in Total Population': '44.995'},
#  'Nepal': {'BRI GDP': '20880545907.4264',
#   'BRI GDP growth rate': '3.36295318337802',
#   'BRI GDP p.c.': '732.298716316243',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.13415578359164',
#   'BRI Agriculture value added per sector ': '13.830656461372',
#   'BRI Industry value added per sector ': '15.6633876230348',
#   'BRI Services value added per sector ': '51.5505780300137',
#   'BRI Population density (/km2)': '198.909661667248',
#   'BRI Percentage of Urban Population in Total Population': '18.615'},
#  'Serbia': {'BRI GDP': '36513027127.6723',
#   'BRI GDP growth rate': '0.726074886537418',
#   'BRI GDP p.c.': '5143.94992561858',
#   'BRI Y.o.Y. GDP growth rate p.c.': '1.18483227762383',
#   'BRI Agriculture value added per sector ': '32.7860343469515',
#   'BRI Industry value added per sector ': '30.1053105407539',
#   'BRI Services value added per sector ': '60.4319434015695',
#   'BRI Population density (/km2)': '81.1599245369312',
#   'BRI Percentage of Urban Population in Total Population': '55.553'},
#  'Saudi Arabia': {'BRI GDP': '646001866666.667',
#   'BRI GDP growth rate': '3.48565641322274',
#   'BRI GDP p.c.': '20481.7453220484',
#   'BRI Y.o.Y. GDP growth rate p.c.': '1.34041487086908',
#   'BRI Agriculture value added per sector ': '9.46274605767656',
#   'BRI Industry value added per sector ': '45.8979065901564',
#   'BRI Services value added per sector ': '51.8379926249955',
#   'BRI Population density (/km2)': '14.6720559708609',
#   'BRI Percentage of Urban Population in Total Population': '83.13'},
#  'Sri Lanka': {'BRI GDP': '82316172384.325',
#   'BRI GDP growth rate': '4.78598456723587',
#   'BRI GDP p.c.': '3926.17439589454',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.81139394477039',
#   'BRI Agriculture value added per sector ': '2.26410078484809',
#   'BRI Industry value added per sector ': '30.7102356990977',
#   'BRI Services value added per sector ': '60.6102524404716',
#   'BRI Population density (/km2)': '334.332642321799',
#   'BRI Percentage of Urban Population in Total Population': '18.356'},
#  'Slovakia': {'BRI GDP': '86581789952.3123',
#   'BRI GDP growth rate': '3.59502093291218',
#   'BRI GDP p.c.': '15962.5722388828',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.49186614856126',
#   'BRI Agriculture value added per sector ': '8.67951186043066',
#   'BRI Industry value added per sector ': '34.384839708011',
#   'BRI Services value added per sector ': '61.5662156970323',
#   'BRI Population density (/km2)': '112.794252204292',
#   'BRI Percentage of Urban Population in Total Population': '53.598'},
#  'Slovenia': {'BRI GDP': '42746980843.0904',
#   'BRI GDP growth rate': '2.87916089867399',
#   'BRI GDP p.c.': '20713.0747463331',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.79002881614979',
#   'BRI Agriculture value added per sector ': '4.04894459495668',
#   'BRI Industry value added per sector ': '33.0631143382462',
#   'BRI Services value added per sector ': '64.7589486699775',
#   'BRI Population density (/km2)': '102.471102284012',
#   'BRI Percentage of Urban Population in Total Population': '49.65'},
#  'Tajikistan': {'BRI GDP': '7853450374.0001',
#   'BRI GDP growth rate': '4.19999999999999',
#   'BRI GDP p.c.': '925.91188767081',
#   'BRI Y.o.Y. GDP growth rate p.c.': '1.91479670425866',
#   'BRI Agriculture value added per sector ': '2.17793699177633',
#   'BRI Population density (/km2)': '60.6019934266933',
#   'BRI Percentage of Urban Population in Total Population': '26.782'},
#  'Thailand': {'BRI GDP': '395281580952.881',
#   'BRI GDP growth rate': '2.81968312231784',
#   'BRI GDP p.c.': '5816.44068998475',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.46658889070383',
#   'BRI Population density (/km2)': '133.021509522598',
#   'BRI Percentage of Urban Population in Total Population': '50.374'},
#  'Turkey': {'BRI GDP': '718221078308.824',
#   'BRI GDP p.c.': '9130.02606479616',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.47524471544042',
#   'BRI Industry value added per sector ': '26.4912091465332',
#   'BRI Services value added per sector ': '64.9192896320277',
#   'BRI Population density (/km2)': '102.212530696568',
#   'BRI Percentage of Urban Population in Total Population': '73.397'},
#  'Turkmenistan': {'BRI GDP': '37334232257.1429',
#   'BRI GDP growth rate': '3.98485920209721',
#   'BRI GDP p.c.': '6947.84002260404',
#   'BRI Y.o.Y. GDP growth rate p.c.': '5.1856911041976',
#   'BRI Agriculture value added per sector ': '8.58950122143913',
#   'BRI Population density (/km2)': '11.4346860170664',
#   'BRI Percentage of Urban Population in Total Population': '50.037'},
#  'Brunei': {'BRI GDP': '15492035784.4207',
#   'BRI GDP growth rate': '6.49999990951666',
#   'BRI GDP p.c.': '36607.9278817468',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-1.86228579260282',
#   'BRI Population density (/km2)': '80.3013282732448',
#   'BRI Percentage of Urban Population in Total Population': '77.202'},
#  'Ukraine': {'BRI GDP': '90615023323.7353',
#   'BRI GDP growth rate': '-0.5',
#   'BRI GDP p.c.': '2114.95471628444',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-9.57171491891337',
#   'BRI Industry value added per sector ': '25.9104766821382',
#   'BRI Services value added per sector ': '60.0531887054144',
#   'BRI Population density (/km2)': '78.0194020575848',
#   'BRI Percentage of Urban Population in Total Population': '69.695'},
#  'Uzbekistan': {'BRI GDP': '66732801392.6618',
#   'BRI GDP growth rate': '7.99999999999994',
#   'BRI GDP p.c.': '2132.07244181734',
#   'BRI Y.o.Y. GDP growth rate p.c.': '6.13050048722816',
#   'BRI Agriculture value added per sector ': '14.0363346124475',
#   'BRI Industry value added per sector ': '34.6262346289219',
#   'BRI Services value added per sector ': '47.1103108990293',
#   'BRI Population density (/km2)': '73.5766337564645',
#   'BRI Percentage of Urban Population in Total Population': '36.365'},
#  'Singapore': {'BRI GDP': '292739307535.642',
#   'BRI GDP growth rate': '2.008372345195',
#   'BRI GDP p.c.': '52888.7446717529',
#   'BRI Y.o.Y. GDP growth rate p.c.': '0.805319025620818',
#   'BRI Agriculture value added per sector ': '18.2634544720488',
#   'BRI Population density (/km2)': '7828.85714285714',
#   'BRI Percentage of Urban Population in Total Population': '100'},
#  'Hungary': {'BRI GDP': '120687138088.121',
#   'BRI GDP growth rate': '2.93891579055648',
#   'BRI GDP p.c.': '12259.1150279573',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.16667475247256',
#   'BRI Population density (/km2)': '108.745012702971',
#   'BRI Percentage of Urban Population in Total Population': '71.227'},
#  'Syria': {'BRI Population density (/km2)': '100.75920601209',
#   'BRI Percentage of Urban Population in Total Population': '57.656'},
#  'Armenia': {'BRI GDP': '10561401185.098',
#   'BRI GDP growth rate': '3.00000000125773',
#   'BRI GDP p.c.': '3499.80421759862',
#   'BRI Y.o.Y. GDP growth rate p.c.': '2.60550443640113',
#   'BRI Agriculture value added per sector ': '19.3520404502788',
#   'BRI Industry value added per sector ': '28.7222907426849',
#   'BRI Services value added per sector ': '51.9256688070363',
#   'BRI Population density (/km2)': '105.996206533193',
#   'BRI Percentage of Urban Population in Total Population': '62.673'},
#  'Yemen': {'BRI Population density (/km2)': '50.8214765990492',
#   'BRI Percentage of Urban Population in Total Population': '34.606'},
#  'Iraq': {'BRI GDP': '168606686710.642',
#   'BRI GDP growth rate': '2.09999999999999',
#   'BRI GDP p.c.': '4629.07663359338',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-1.12390085273492',
#   'BRI Population density (/km2)': '83.8630387732547',
#   'BRI Percentage of Urban Population in Total Population': '69.471'},
#  'Iran': {'BRI Population density (/km2)': '48.5765079365079',
#   'BRI Percentage of Urban Population in Total Population': '73.375'},
#  'Israel': {'BRI GDP': '296075434804.981',
#   'BRI GDP growth rate': '2.48807622448481',
#   'BRI GDP p.c.': '35329.5110979167',
#   'BRI Y.o.Y. GDP growth rate p.c.': '0.473878077120403',
#   'BRI Population density (/km2)': '387.264325323475',
#   'BRI Percentage of Urban Population in Total Population': '92.14'},
#  'India': {'BRI GDP': '2073542978208.77',
#   'BRI GDP growth rate': '7.57013036787396',
#   'BRI GDP p.c.': '1581.58891324619',
#   'BRI Y.o.Y. GDP growth rate p.c.': '6.27712454663818',
#   'BRI Population density (/km2)': '440.957532818286',
#   'BRI Percentage of Urban Population in Total Population': '32.747'},
#  'Indonesia': {'BRI GDP': '861933968740.332',
#   'BRI GDP growth rate': '4.7939213038221',
#   'BRI GDP p.c.': '3346.48703949478',
#   'BRI Y.o.Y. GDP growth rate p.c.': '3.52896031266474',
#   'BRI Agriculture value added per sector ': '13.520732350571',
#   'BRI Industry value added per sector ': '40.0148073054757',
#   'BRI Services value added per sector ': '43.3238451323323',
#   'BRI Population density (/km2)': '142.177125366395',
#   'BRI Percentage of Urban Population in Total Population': '53.742'},
#  'Jordan': {'BRI GDP': '37517410299.2739',
#   'BRI GDP growth rate': '2.38268662851466',
#   'BRI GDP p.c.': '4940.04583805643',
#   'BRI Y.o.Y. GDP growth rate p.c.': '-0.0232006201219406',
#   'BRI Agriculture value added per sector ': '4.17398422334225',
#   'BRI Industry value added per sector ': '29.6406318271146',
#   'BRI Services value added per sector ': '66.1853839495433',
#   'BRI Population density (/km2)': '85.5434444694751',
#   'BRI Percentage of Urban Population in Total Population': '83.679'},
#  'Vietnam': {'BRI GDP': '193599379094.859',
#   'BRI GDP growth rate': '6.67928878891431',
#   'BRI GDP p.c.': '2111.13802366815',
#   'BRI Y.o.Y. GDP growth rate p.c.': '5.54518487347883',
#   'BRI Agriculture value added per sector ': '16.9922120022076',
#   'BRI Industry value added per sector ': '33.2500807324448',
#   'BRI Services value added per sector ': '39.7332895764278',
#   'BRI Population density (/km2)': '295.751926984229',
#   'BRI Percentage of Urban Population in Total Population': '33.593'}}

# %%
# Add data to df
for country in yidaiyilu_data.keys():
    original_name = country
    global_rate = 0
    if country == "Thailand":
        original_name = "Thailiand"
    for indic in yidaiyilu_data[country]:
        if pd.isnull(df[indic].iloc[df['Country (according to CN Gov):'][df['Country (according to CN Gov):'] == original_name].index[0]-1]):
            value = yidaiyilu_data[country][indic]
            df[indic].iloc[df['Country (according to CN Gov):'][df['Country (according to CN Gov):'] == original_name].index[0]-1] = value
            if "sector" in indic:
                global_rate += float(value)
        if global_rate > 0 :
            df["Cumulative value added (numbers should reflect 100%)"].iloc[df['Country (according to CN Gov):'][df['Country (according to CN Gov):'] == original_name].index[0]-1] = value

# %%
# Get the data from HF source
hf_data_source = pd.read_excel('data_files/index2019_data.xls', index_col=0)

# %%
# Object with final data
hf_data_keep = {}

# %%
# Check if we have the right countries
for my_country in isocodes:
    for index, country in hf_data_source['Country Name'].items():
        if country == my_country or country == isocodes[my_country]['other']:
            hf_data_keep[my_country] = {"index" : index}

# %%
for country in hf_data_keep:
    rank = hf_data_source.loc[hf_data_keep[country]['index'],'World Rank']
    scale = hf_data_source.loc[hf_data_keep[country]['index'],'2019 Score']
           
    hf_data_keep[country].update({"rank" : rank})
    hf_data_keep[country].update({"scale" : scale})

# %%
hf_data_keep
# Out:
# {'Afghanistan': {'index': 1, 'rank': 152.0, 'scale': 51.5},
#  'Albania': {'index': 2, 'rank': 52.0, 'scale': 66.5},
#  'Armenia': {'index': 6, 'rank': 47.0, 'scale': 67.7},
#  'Azerbaijan': {'index': 9, 'rank': 60.0, 'scale': 65.4},
#  'Bahrain': {'index': 11, 'rank': 54.0, 'scale': 66.4},
#  'Bangladesh': {'index': 12, 'rank': 121.0, 'scale': 55.6},
#  'Belarus': {'index': 14, 'rank': 104.0, 'scale': 57.9},
#  'Bhutan': {'index': 18, 'rank': 74.0, 'scale': 62.9},
#  'Bosnia and Herzegovina': {'index': 20, 'rank': 83.0, 'scale': 61.9},
#  'Brunei': {'index': 186, 'rank': 63.0, 'scale': 65.1},
#  'Bulgaria': {'index': 23, 'rank': 37.0, 'scale': 69.0},
#  'Cambodia': {'index': 27, 'rank': 105.0, 'scale': 57.8},
#  'China': {'index': 34, 'rank': 100.0, 'scale': 58.4},
#  'Croatia': {'index': 41, 'rank': 86.0, 'scale': 61.4},
#  'Czech Republic': {'index': 44, 'rank': 23.0, 'scale': 73.7},
#  'East Timor': {'index': 164, 'rank': 172.0, 'scale': 44.2},
#  'Egypt': {'index': 50, 'rank': 144.0, 'scale': 52.5},
#  'Estonia': {'index': 54, 'rank': 15.0, 'scale': 76.6},
#  'France (Not BRI)': {'index': 58, 'rank': 71.0, 'scale': 63.8},
#  'Georgia': {'index': 61, 'rank': 16.0, 'scale': 75.9},
#  'Germany (not BRI)': {'index': 62, 'rank': 24.0, 'scale': 73.5},
#  'Hungary': {'index': 72, 'rank': 64.0, 'scale': 65.0},
#  'India': {'index': 74, 'rank': 129.0, 'scale': 55.2},
#  'Indonesia': {'index': 75, 'rank': 56.0, 'scale': 65.8},
#  'Iran': {'index': 76, 'rank': 155.0, 'scale': 51.1},
#  'Iraq': {'index': 77, 'rank': nan, 'scale': nan},
#  'Israel': {'index': 79, 'rank': 27.0, 'scale': 72.8},
#  'Jordan': {'index': 83, 'rank': 53.0, 'scale': 66.5},
#  'Kazakhstan': {'index': 84, 'rank': 59.0, 'scale': 65.4},
#  'Kuwait': {'index': 89, 'rank': 90.0, 'scale': 60.8},
#  'Kyrgyzstan': {'index': 90, 'rank': 79.0, 'scale': 62.3},
#  'Laos': {'index': 91, 'rank': 110.0, 'scale': 57.4},
#  'Latvia': {'index': 92, 'rank': 35.0, 'scale': 70.4},
#  'Lebanon': {'index': 93, 'rank': 154.0, 'scale': 51.1},
#  'Lithuania': {'index': 98, 'rank': 21.0, 'scale': 74.2},
#  'Macedonia': {'index': 101, 'rank': 33.0, 'scale': 71.1},
#  'Malaysia': {'index': 104, 'rank': 22.0, 'scale': 74.0},
#  'Maldives': {'index': 105, 'rank': 141.0, 'scale': 53.2},
#  'Moldova': {'index': 112, 'rank': 97.0, 'scale': 59.1},
#  'Mongolia': {'index': 113, 'rank': 126.0, 'scale': 55.4},
#  'Montenegro': {'index': 114, 'rank': 92.0, 'scale': 60.5},
#  'Myanmar': {'index': 25, 'rank': 139.0, 'scale': 53.6},
#  'Nepal': {'index': 118, 'rank': 136.0, 'scale': 53.8},
#  'Oman': {'index': 125, 'rank': 88.0, 'scale': 61.0},
#  'Pakistan': {'index': 126, 'rank': 131.0, 'scale': 55.0},
#  'Philippines': {'index': 131, 'rank': 70.0, 'scale': 63.8},
#  'Poland': {'index': 132, 'rank': 46.0, 'scale': 67.8},
#  'Qatar': {'index': 134, 'rank': 28.0, 'scale': 72.6},
#  'Romania': {'index': 135, 'rank': 42.0, 'scale': 68.6},
#  'Russia': {'index': 136, 'rank': 98.0, 'scale': 58.9},
#  'Saudi Arabia': {'index': 142, 'rank': 91.0, 'scale': 60.7},
#  'Serbia': {'index': 144, 'rank': 69.0, 'scale': 63.9},
#  'Singapore': {'index': 147, 'rank': 2.0, 'scale': 89.4},
#  'Slovakia': {'index': 148, 'rank': 65.0, 'scale': 65.0},
#  'Slovenia': {'index': 149, 'rank': 58.0, 'scale': 65.5},
#  'Sri Lanka': {'index': 153, 'rank': 115.0, 'scale': 56.4},
#  'Syria': {'index': 159, 'rank': nan, 'scale': nan},
#  'Tajikistan': {'index': 161, 'rank': 122.0, 'scale': 55.6},
#  'Thailiand': {'index': 163, 'rank': 43.0, 'scale': 68.3},
#  'The United Arab Emirates': {'index': 173, 'rank': 9.0, 'scale': 77.6},
#  'Turkey': {'index': 169, 'rank': 68.0, 'scale': 64.6},
#  'Turkmenistan': {'index': 170, 'rank': 164.0, 'scale': 48.4},
#  'United Kingdom (Not BRI)': {'index': 174, 'rank': 7.0, 'scale': 78.9},
#  'Ukraine': {'index': 172, 'rank': 147.0, 'scale': 52.3},
#  'Uzbekistan': {'index': 177, 'rank': 140.0, 'scale': 53.3},
#  'Vietnam': {'index': 180, 'rank': 128.0, 'scale': 55.3},
#  'Yemen': {'index': 181, 'rank': nan, 'scale': nan}}

# %%
# Add data to df
for country in hf_data_keep.keys():
    if pd.isnull( df['HF Index of Economic Freedom (Scale: 1-100)'].iloc[list(isocodes).index(country)]):
        df['HF Index of Economic Freedom (Scale: 1-100)'].iloc[list(isocodes).index(country)] = hf_data_keep[country]['scale']
    if pd.isnull( df['Heritage Foundation Index of Economic Freedom (Global Ranking)'].iloc[list(isocodes).index(country)]):
        df['Heritage Foundation Index of Economic Freedom (Global Ranking)'].iloc[list(isocodes).index(country)] = hf_data_keep[country]['rank']

# %%
# Get the data from BTI source
bti_data_source = pd.read_excel('data_files/BTI_2018_Scores.xlsx')

# %%
# Object with final data
bti_data_keep = {}

# %%
# Check if we have the right countries
for my_country in isocodes:
    for index, country in bti_data_source['Regions:\n1 | East-Central and Southeast Europe\n2 | Latin America and the Caribbean\n3 | West and Central Africa\n4 | Middle East and North Africa\n5 | South and East Africa\n6 | Post-Soviet Eurasia\n7 | Asia and Oceania'].items():
        if country == my_country or country == isocodes[my_country]['other']:
            bti_data_keep[my_country] = {"index" : index}

# %%
for country in bti_data_keep:
    rank = bti_data_source.loc[bti_data_keep[country]['index'],'  Ranking Status Index']
    scale = bti_data_source.loc[bti_data_keep[country]['index'],'  S | Status Index']
                               
    bti_data_keep[country].update({"rank" : rank})
    bti_data_keep[country].update({"scale" : scale})

# %%
bti_data_keep
# Out:
# {'Afghanistan': {'index': 0, 'rank': 121, 'scale': 2.954761904761905},
#  'Albania': {'index': 1, 'rank': 30, 'scale': 6.828571428571428},
#  'Armenia': {'index': 5, 'rank': 61, 'scale': 5.576190476190476},
#  'Azerbaijan': {'index': 6, 'rank': 100, 'scale': 4.127380952380952},
#  'Bahrain': {'index': 7, 'rank': 89, 'scale': 4.616666666666667},
#  'Bangladesh': {'index': 8, 'rank': 79, 'scale': 5.1119047619047615},
#  'Belarus': {'index': 9, 'rank': 86, 'scale': 4.720238095238095},
#  'Bhutan': {'index': 11, 'rank': 45, 'scale': 6.2476190476190485},
#  'Bosnia and Herzegovina': {'index': 13,
#   'rank': 43,
#   'scale': 6.282142857142857},
#  'Bulgaria': {'index': 16, 'rank': 17, 'scale': 7.8},
#  'Cambodia': {'index': 19, 'rank': 103, 'scale': 3.9976190476190476},
#  'China': {'index': 24, 'rank': 81, 'scale': 5.016666666666667},
#  'Croatia': {'index': 30, 'rank': 14, 'scale': 8.067857142857143},
#  'Czech Republic': {'index': 32, 'rank': 1, 'scale': 9.521428571428572},
#  'Egypt': {'index': 35, 'rank': 96, 'scale': 4.2785714285714285},
#  'Estonia': {'index': 38, 'rank': 1, 'scale': 9.517857142857142},
#  'Georgia': {'index': 40, 'rank': 42, 'scale': 6.417857142857143},
#  'Hungary': {'index': 46, 'rank': 18, 'scale': 7.432142857142857},
#  'India': {'index': 47, 'rank': 26, 'scale': 6.960714285714285},
#  'Indonesia': {'index': 48, 'rank': 45, 'scale': 6.25},
#  'Iran': {'index': 49, 'rank': 118, 'scale': 3.154761904761905},
#  'Iraq': {'index': 50, 'rank': 107, 'scale': 3.7464285714285714},
#  'Jordan': {'index': 52, 'rank': 72, 'scale': 5.219047619047618},
#  'Kazakhstan': {'index': 53, 'rank': 88, 'scale': 4.703571428571428},
#  'Kuwait': {'index': 56, 'rank': 60, 'scale': 5.607142857142858},
#  'Kyrgyzstan': {'index': 57, 'rank': 55, 'scale': 5.896428571428572},
#  'Laos': {'index': 58, 'rank': 106, 'scale': 3.8511904761904763},
#  'Latvia': {'index': 59, 'rank': 8, 'scale': 8.678571428571429},
#  'Lebanon': {'index': 60, 'rank': 74, 'scale': 5.147619047619047},
#  'Lithuania': {'index': 64, 'rank': 4, 'scale': 9.242857142857144},
#  'Macedonia': {'index': 65, 'rank': 31, 'scale': 6.760714285714286},
#  'Malaysia': {'index': 68, 'rank': 53, 'scale': 5.998809523809523},
#  'Moldova': {'index': 73, 'rank': 54, 'scale': 5.957142857142857},
#  'Mongolia': {'index': 74, 'rank': 34, 'scale': 6.592857142857143},
#  'Montenegro': {'index': 75, 'rank': 20, 'scale': 7.3464285714285715},
#  'Myanmar': {'index': 78, 'rank': 111, 'scale': 3.375},
#  'Nepal': {'index': 80, 'rank': 92, 'scale': 4.521428571428572},
#  'Oman': {'index': 85, 'rank': 93, 'scale': 4.428571428571429},
#  'Pakistan': {'index': 86, 'rank': 102, 'scale': 4.010714285714286},
#  'Philippines': {'index': 91, 'rank': 38, 'scale': 6.4714285714285715},
#  'Poland': {'index': 92, 'rank': 10, 'scale': 8.57857142857143},
#  'Qatar': {'index': 93, 'rank': 56, 'scale': 5.8845238095238095},
#  'Romania': {'index': 94, 'rank': 15, 'scale': 8.057142857142857},
#  'Russia': {'index': 95, 'rank': 70, 'scale': 5.310714285714285},
#  'Saudi Arabia': {'index': 97, 'rank': 97, 'scale': 4.265476190476191},
#  'Serbia': {'index': 99, 'rank': 19, 'scale': 7.4035714285714285},
#  'Singapore': {'index': 101, 'rank': 24, 'scale': 7.154761904761904},
#  'Slovakia': {'index': 102, 'rank': 9, 'scale': 8.585714285714285},
#  'Slovenia': {'index': 103, 'rank': 6, 'scale': 9.178571428571429},
#  'Sri Lanka': {'index': 108, 'rank': 33, 'scale': 6.614285714285714},
#  'Syria': {'index': 110, 'rank': 128, 'scale': 1.5714285714285714},
#  'Tajikistan': {'index': 112, 'rank': 115, 'scale': 3.3130952380952383},
#  'Thailiand': {'index': 114, 'rank': 87, 'scale': 4.714285714285714},
#  'The United Arab Emirates': {'index': 121,
#   'rank': 52,
#   'scale': 6.071428571428571},
#  'Turkey': {'index': 117, 'rank': 51, 'scale': 6.167857142857143},
#  'Turkmenistan': {'index': 118, 'rank': 119, 'scale': 3.1392857142857142},
#  'Ukraine': {'index': 120, 'rank': 36, 'scale': 6.539285714285715},
#  'Uzbekistan': {'index': 123, 'rank': 108, 'scale': 3.7261904761904763},
#  'Vietnam': {'index': 125, 'rank': 94, 'scale': 4.4071428571428575},
#  'Yemen': {'index': 126, 'rank': 127, 'scale': 1.7214285714285715}}

# %%
# Add data to df
for country in bti_data_keep.keys():
    if pd.isnull( df['Bertelsmann Transformation index (BTI)'].iloc[list(isocodes).index(country)]):
        df['Bertelsmann Transformation index (BTI)'].iloc[list(isocodes).index(country)] = bti_data_keep[country]['scale']
    if pd.isnull( df['Bertelsmann Transformation index (BTI) - Ranking'].iloc[list(isocodes).index(country)]):
        df['Bertelsmann Transformation index (BTI) - Ranking'].iloc[list(isocodes).index(country)] = bti_data_keep[country]['rank']

# %%
# Save isocodes object for later use
with open('objects_saved/isocodes.pkl', 'wb') as handle:
  pickle.dump(isocodes, handle)

# %%
df.to_pickle("objects_saved/data.pkl")
